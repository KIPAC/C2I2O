# %%
import c2i2o
#from c2i2o.functions.scipy_wrap import ScipyWrapped, union_model
from c2i2o.data_model.prior_set import PriorSet
from pydantic_yaml import parse_yaml_raw_as
import corner
import numpy as np

# %%
data_dir = "."
n_samples = 10000

# %%
prior_file = f"{data_dir}/prior.yaml"
with open(prior_file, 'r') as fin:
    prior_data = fin.read()
prior_set = parse_yaml_raw_as(PriorSet, prior_data)

# %%
table = prior_set.generate_data(n_samples)

# %%
table
